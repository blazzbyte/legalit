# %% [markdown]
# # Analysis of the Documents before proccesing

# %%
import pickle

# Load the list from the file
with open('documents.pkl', 'rb') as file:
    documents = pickle.load(file)

# %%
documents[0]
# Out:
# Document(id_='24aac17d-e53d-41b7-b6f3-3c4c9f901ede', embedding=None, metadata={'languages': ['eng'], 'page_number': 1, 'filename': 'tmp\\ObliCon-1-5.pdf', 'filetype': 'application/pdf', 'user_id': 'default'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, text='TITLE I – OBLIGATIONS', start_char_idx=None, end_char_idx=None, text_template='{metadata_str}\n\n{content}', metadata_template='{key}: {value}', metadata_seperator='\n')

# %%
from json import dumps
print(dumps([{'content': doc.text, 'metadata': doc.metadata} for doc in documents], indent=2))
# Out:
# [
#   {
#     "content": "TITLE I \u2013 OBLIGATIONS",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "page_number": 1,
#       "filename": "tmp\\ObliCon-1-5.pdf",
#       "filetype": "application/pdf",
#       "user_id": "default"
#     }
#   },
#   {
#     "content": "CHAPTER 1 GENERAL PROVISIONS",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "page_number": 1,
#       "filename": "tmp\\ObliCon-1-5.pdf",
#       "filetype": "application/pdf",
#       "user_id": "default"
#     }
#   },
#   {
#     "content": "1156. An obligation is a juridical necessity to give, to do, or not to do.",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "page_number": 1,
#       "filename": "tmp\\ObliCon-1-5.pdf",
#       "filetype": "application/pdf",
#       "user_id": "default"
#     }
#   },
#   {
# ...

# %%
len(documents)
# Out:
# 243

# %%
page_1 = [{'content': doc.text, 'metadata': doc.metadata} for doc in documents if doc.metadata['page_number']==1]
print(dumps(page_1, indent=2))
# Out:
# [
#   {
#     "content": "TITLE I \u2013 OBLIGATIONS",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "page_number": 1,
#       "filename": "tmp\\ObliCon-1-5.pdf",
#       "filetype": "application/pdf",
#       "user_id": "default"
#     }
#   },
#   {
#     "content": "CHAPTER 1 GENERAL PROVISIONS",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "page_number": 1,
#       "filename": "tmp\\ObliCon-1-5.pdf",
#       "filetype": "application/pdf",
#       "user_id": "default"
#     }
#   },
#   {
#     "content": "1156. An obligation is a juridical necessity to give, to do, or not to do.",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "page_number": 1,
#       "filename": "tmp\\ObliCon-1-5.pdf",
#       "filetype": "application/pdf",
#       "user_id": "default"
#     }
#   },
#   {
# ...

# %%
len(page_1)
# Out:
# 46

# %%
page_2 = [{'content': doc.text, 'metadata': doc.metadata} for doc in documents if doc.metadata['page_number']==2]
print(dumps(page_2, indent=2))
# Out:
# [
#   {
#     "content": "between parties; neither party may unilaterally evade his obligation in the contract, unless: contract authorizes it",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "page_number": 2,
#       "filename": "tmp\\ObliCon-1-5.pdf",
#       "filetype": "application/pdf",
#       "user_id": "default"
#     }
#   },
#   {
#     "content": "a) b) other party assents",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "page_number": 2,
#       "filename": "tmp\\ObliCon-1-5.pdf",
#       "filetype": "application/pdf",
#       "user_id": "default"
#     }
#   },
#   {
#     "content": "Note: Parties may freely enter into any stipulations, provided they are not contrary to law, morals, good customs, public order or public policy - [See Article 1159]",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "page_number": 2,
#       "filename": "tmp\\ObliCon-1-5.pdf",
# ...

# %%
len(page_2)
# Out:
# 42

# %%
page_3 = [{'content': doc.text, 'metadata': doc.metadata} for doc in documents if doc.metadata['page_number']==3]
print(dumps(page_3, indent=2))
# Out:
# [
#   {
#     "content": "when there is no right to demand it and it was unduly delivered through mistake; obligation to return the thing arises on the part of the recipient. (e.g. If I let a storekeeper change my P500 bill and by error he gives me P560, I have the duty to return the extra P60)",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "page_number": 3,
#       "filename": "tmp\\ObliCon-1-5.pdf",
#       "filetype": "application/pdf",
#       "user_id": "default"
#     }
#   },
#   {
#     "content": "1161. Civil obligations arising from criminal offenses shall be governed by the penal laws, subject to the provisions of Article 2177, and of the pertinent provisions of Chapter 2, Preliminary in Human Relations, and of Title 18 of this book, regulating damages. Governing rules:",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "page_number": 3,
#       "filename": "tmp\\ObliCon-1-5.pdf",
# ...

# %%
len(page_3)
# Out:
# 52

# %%
page_4 = [{'content': doc.text, 'metadata': doc.metadata} for doc in documents if doc.metadata['page_number']==4]
print(dumps(page_4, indent=2))
# Out:
# [
#   {
#     "content": "",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "page_number": 4,
#       "filename": "tmp\\ObliCon-1-5.pdf",
#       "filetype": "application/pdf",
#       "user_id": "default"
#     }
#   },
#   {
#     "content": "thing (that is one which is specific; a thing identified by its individuality) which an obligor is supposed to deliver to another. Reason: the obligor cannot take care of the whole class/genus",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "page_number": 4,
#       "filename": "tmp\\ObliCon-1-5.pdf",
#       "filetype": "application/pdf",
#       "user_id": "default"
#     }
#   },
#   {
#     "content": "DUTIES OF DEBTOR:",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "page_number": 4,
#       "filename": "tmp\\ObliCon-1-5.pdf",
#       "filetype": "application/pdf",
#       "user_id": "default"
#     }
#   },
#   {
#     "content": "",
# ...

# %%
len(page_4)
# Out:
# 50

# %%
page_5 = [{'content': doc.text, 'metadata': doc.metadata} for doc in documents if doc.metadata['page_number']==5]
print(dumps(page_5, indent=2))
# Out:
# [
#   {
#     "content": "accessories, even though they may not have been mentioned.",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "page_number": 5,
#       "filename": "tmp\\ObliCon-1-5.pdf",
#       "filetype": "application/pdf",
#       "user_id": "default"
#     }
#   },
#   {
#     "content": "ACCESSIONS \u2013 fruits of the thing or additions to or improvements upon the principal \uf02d",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "page_number": 5,
#       "filename": "tmp\\ObliCon-1-5.pdf",
#       "filetype": "application/pdf",
#       "user_id": "default"
#     }
#   },
#   {
#     "content": "those which are naturally or artificially attached to the thing",
#     "metadata": {
#       "languages": [
#         "eng"
#       ],
#       "page_number": 5,
#       "filename": "tmp\\ObliCon-1-5.pdf",
#       "filetype": "application/pdf",
#       "user_id": "default"
#     }
#   },
#   {
# ...

# %%
len(page_5)
# Out:
# 53

# %%
53+50+52+42+46
# Out:
# 243

# %%
len(documents)==len(page_5)+len(page_4)+len(page_3)+len(page_2)+len(page_1)
# Out:
# True

# %% [markdown]
# # Analisys from documents1

# %%
import pickle
from json import dumps

# Load the list from the file
with open('documents1.pkl', 'rb') as file:
    documents1 = pickle.load(file)

# %%
print(dumps([{'content': doc.text, 'metadata': doc.metadata} for doc in documents1], indent=2))
# Out:
# [
#   {
#     "content": "TITLE I \u2013 OBLIGATIONS",
#     "metadata": {
#       "user_id": "default",
#       "title": "tmp\\ObliCon-1-5.pdf"
#     }
#   },
#   {
#     "content": "CHAPTER 1 GENERAL PROVISIONS",
#     "metadata": {
#       "user_id": "default",
#       "title": "tmp\\ObliCon-1-5.pdf"
#     }
#   },
#   {
#     "content": "1156. An obligation is a juridical necessity to give, to do, or not to do.",
#     "metadata": {
#       "user_id": "default",
#       "title": "tmp\\ObliCon-1-5.pdf"
#     }
#   },
#   {
#     "content": "JURIDICAL NECESSITY \u2013 juridical tie; connotes that in case of noncompliance, there will be legal sanctions.",
#     "metadata": {
#       "user_id": "default",
#       "title": "tmp\\ObliCon-1-5.pdf"
#     }
#   },
#   {
#     "content": "",
#     "metadata": {
#       "user_id": "default",
#       "title": "tmp\\ObliCon-1-5.pdf"
#     }
#   },
#   {
# ...

# %%
len(documents1)
# Out:
# 243
